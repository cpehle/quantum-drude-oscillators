# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(file("numbers").readlines()[5:])
print np.mean(data[500:,1])
plt.plot(data[:,1])
# Out:
# 1.49919836667

# %%
plt.plot(data[:,0])
